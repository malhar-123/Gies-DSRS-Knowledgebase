# %% [markdown]
# <a href="https://colab.research.google.com/github/malhar-123/Gies-DSRS-Knowledgebase/blob/main/DSRS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##DSRS Knowledge Base Project - README
#
# ##- Overview
#
# The Data Science Research Services (DSRS) at the University of Illinois provides researchers with data science consulting, secure infrastructure, licensed datasets, and advanced computing tools. This project creates an automated, structured knowledge base from DSRS's publicly available resources to aid new joiners, collaborators, and external researchers.
#
#  ##-Project Purpose
#
# This notebook crawls, indexes, and organizes DSRS-related content from:
#
# https://dsrs.illinois.edu/
#
# In future phases, it will expand to include:
#
# https://github.com/giesdsrs
#
# https://dsrs.illinois.edu/datahub/category
#
# https://giesbusiness.illinois.edu/disruption-lab
#
# The core output is a searchable, structured JSON and SQLite knowledge base.
#
#  ##-Functionality Summary
#
# Web Crawler: Extracts text from paragraphs, classifies it into logical sections.
#
# Keyword Extractor: Identifies and indexes top keywords from each page.
#
# JSON Export: Saves the knowledge base in a structured .json format.
#
# Keyword Search: Allows users to retrieve relevant pages based on keyword matches.
#
# Graph Visualization: Depicts conceptual data flows across DSRS components (Datasets → Projects → Services → Tools, etc.).
#
# ###-  Data Schema
#
# Each crawled entry is structured using the following fields:
#
#  **url**: Source URL of the crawled page
#  **title**: Page or section title
#  **section**: Classified section (e.g., Services, Tools)
#  **content**: Main body text extracted from the page
#  **keywords**: Auto-extracted keywords (top 5) for quick retrieval
#  **last_crawled**: Timestamp of the last time the page was crawled
#
#  ## - How Users Can Interact
#
# Search: Enter any keyword to retrieve matching knowledge entries.
#
# Explore Graph: View how different DSRS resources conceptually relate.
#
# Extend or Update: Add more URLs or re-run the notebook to refresh content.
#
# ##- Maintenance Strategy
#
# Each crawl stores last_crawled timestamps.
#
# Duplicate pages are updated using ON CONFLICT logic.
#
# Can be scheduled (via cron or GitHub Actions) to refresh monthly.
#
#  ##-Future Scope
#
# Iterative (BFS) Crawl: Switch to a breadth-first strategy to better prioritize public-facing summary pages.
#
# Full Site Expansion: Crawl GitHub repositories, DataHub catalogs, and the Gies Disruption Lab.
#
# Semantic Search: Add OpenAI or embedding-based models for natural language queries.
#
# Onboarding Assistant: Build an FAQ/chat interface for new DSRS members or interns.
#
# ## Knowledge Architecture: How DSRS Components Relate
#
# **Services** → use **Technical Tools** like Azure, JupyterHub, and MinIO.
# **Projects** → are supported by **Services** (consulting, analytics) and **Tools** (secure compute, databases).
# **Datasets** → power **Projects** and are curated through **DataHub**.
# **Internships** and **Collaborations** → emerge from real-world application of **Projects** and **Services**.
#
# This structure ensures a connected ecosystem: tools and services support research, which in turn enables learning, collaboration, and innovation.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import sqlite3
import time
import re
import pandas as pd
import json
from datetime import datetime

# Initialize
START_URLS = ["https://dsrs.illinois.edu/"]
urls_to_visit = deque(START_URLS)
visited_urls = set()
extracted_data = []

# Section classifiers
SECTION_MAP = {
    "about": "Overview",
    "services": "Services",
    "projects": "Projects",
    "news": "Events",
    "tools": "Technical Resources",
    "team": "Team",
    "students": "Internships",
    "datahub": "Datasets",
    "github": "Open Source Projects",
    "disruption-lab": "Collaborations"
}

# DB Setup
def init_db():
    conn = sqlite3.connect("dsrs_kb.db")
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS knowledge_base (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            url TEXT UNIQUE,
            title TEXT,
            section TEXT,
            content TEXT,
            keywords TEXT,
            last_crawled TEXT
        )
    """)
    conn.commit()
    conn.close()

def export_to_json(data, filename="dsrs_kb1.json"):
    json_data = [
        {
            "url": entry[0],
            "title": entry[1],
            "section": entry[2],
            "content": entry[3],
            "keywords": entry[4],
            "last_crawled": entry[5]
        }
        for entry in data
    ]
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(json_data, f, indent=4, ensure_ascii=False)
    print(f"\n Exported knowledge base to {filename}")

def extract_keywords(text, top_k=5):
    words = re.findall(r'\b\w{5,}\b', text.lower())
    freq = pd.Series(words).value_counts()
    return ', '.join(freq.head(top_k).index)

def classify_section(url, title):
    for key in SECTION_MAP:
        if key in url.lower() or key in title.lower():
            return SECTION_MAP[key]
    return "Uncategorized"

def is_valid_url(url):
    parsed = urlparse(url)
    return parsed.netloc.endswith("dsrs.illinois.edu")

def crawl(url):
    if url in visited_urls:
        return
    visited_urls.add(url)
    try:
        print(f"Processing: {url}")
        response = requests.get(url)
        response.raise_for_status()
    except requests.RequestException as e:
        print(f" Failed to fetch {url}: {e}")
        return

    soup = BeautifulSoup(response.text, 'html.parser')
    title = soup.title.string.strip() if soup.title else "No Title"
    section = classify_section(url, title)

    paragraphs = [p.get_text(strip=True) for p in soup.find_all('p') if len(p.get_text(strip=True)) > 30]
    full_text = " ".join(paragraphs)
    if not full_text:
        return

    keywords = extract_keywords(full_text)
    last_crawled = datetime.now().isoformat()
    extracted_data.append((url, title, section, full_text, keywords, last_crawled))

    print(f" Indexed: {url} | Section: {section} | Title: {title}")
    if section in ["Overview", "Services", "Projects", "Technical Resources"]:
        print("\n--- Summary for Knowledge Base Users ---")
        print(f"Section: {section}")
        print(f"Title: {title}")
        print(f"Main Info: {full_text[:300]}...")
        print("---\n")

    for link_tag in soup.find_all('a', href=True):
        full_url = urljoin(url, link_tag['href'])
        if is_valid_url(full_url) and full_url not in visited_urls:
            urls_to_visit.append(full_url)
    time.sleep(0.5)

# Execute
if __name__ == "__main__":
    init_db()
    while urls_to_visit:
        crawl(urls_to_visit.popleft())
    #store_to_db(extracted_data)
    export_to_json(extracted_data)
    print(f"\n Stored {len(extracted_data)} entries in dsrs_kb.json")
# Out:
# Processing: https://dsrs.illinois.edu/
#  Indexed: https://dsrs.illinois.edu/ | Section: Uncategorized | Title: DSRS | DSRS
# Processing: https://dsrs.illinois.edu/#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/#__docusaurus_skipToContent_fallback | Section: Uncategorized | Title: DSRS | DSRS
# Processing: https://dsrs.illinois.edu/about
#  Indexed: https://dsrs.illinois.edu/about | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/faculty
#  Indexed: https://dsrs.illinois.edu/faculty | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students
#  Indexed: https://dsrs.illinois.edu/students | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/intro
#  Indexed: https://dsrs.illinois.edu/datahub/intro | Section: Datasets | Title: Introduction | DSRS
# Processing: https://internal.dsrs.illinois.edu
#  Failed to fetch https://internal.dsrs.illinois.edu: 403 Client Error: Forbidden for url: https://internal.dsrs.illinois.edu/
# Processing: https://dsrs.illinois.edu/about/students
# Processing: https://dsrs.illinois.edu/about#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about#__docusaurus_skipToContent_fallback | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/about/
#  Indexed: https://dsrs.illinois.edu/about/ | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/about/team
#  Indexed: https://dsrs.illinois.edu/about/team | Section: Overview | Title: Team | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Team | DSRS
# Main Info: The DSRS is led by a motivated team of students with diverse backgrounds, skills, and interests. If you want to learn more about opportunities, checkhere DSRS Assistant Director of Administration DSRS Data Scientist & Unit Manager DSRS Data Scientist & Unit Manager These are our former members; DSRS...
# ---
#
# Processing: https://dsrs.illinois.edu/about/infrastructure
#  Indexed: https://dsrs.illinois.edu/about/infrastructure | Section: Overview | Title: Infrastructure | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Infrastructure | DSRS
# Main Info: The DSRS infrastructure's backbone is a high-performance computing cluster consisting of over640 cores, 2.5 TB of RAM, and over 45TB of shared storage, in addition to 2.8 TB of SSD storage. This set up provides substantial computational power to support a multitude of research projects simultaneousl...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq
#  Indexed: https://dsrs.illinois.edu/about/faq | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news
#  Indexed: https://dsrs.illinois.edu/about/news | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/contact
#  Indexed: https://dsrs.illinois.edu/about/contact | Section: Overview | Title: Contact | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Contact | DSRS
# Main Info: Data Science Research Services (DSRS), Gies College of Business Matias Carrasco Kind, DSRS Director515 E Gregory Dr, Champaign, IL 61820dsrs@business.illinois.edu...
# ---
#
# Processing: https://dsrs.illinois.edu/faculty#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/faculty#__docusaurus_skipToContent_fallback | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty/
#  Indexed: https://dsrs.illinois.edu/faculty/ | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty#dsrs-services
#  Indexed: https://dsrs.illinois.edu/faculty#dsrs-services | Section: Services | Title: Overview | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Services
# Title: Overview | DSRS
# Main Info: We assist faculty researchthrough the execution
# of statistical and data science methods, providing
# consultative services and analyses within our
# computational infrastructure. The College has invested in
# DSRS and funds the unit’s consultations and other work. We assess research studiesto determine wh...
# ---
#
# Processing: https://dsrs.illinois.edu/faculty#assistance
#  Indexed: https://dsrs.illinois.edu/faculty#assistance | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty#analyses
#  Indexed: https://dsrs.illinois.edu/faculty#analyses | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty#data
#  Indexed: https://dsrs.illinois.edu/faculty#data | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty#computational-capability
#  Indexed: https://dsrs.illinois.edu/faculty#computational-capability | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty#microsoft-azure
#  Indexed: https://dsrs.illinois.edu/faculty#microsoft-azure | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/students#__docusaurus_skipToContent_fallback | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/
#  Indexed: https://dsrs.illinois.edu/students/ | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/opportunities
#  Indexed: https://dsrs.illinois.edu/students/opportunities | Section: Internships | Title: Opportunities | DSRS
# Processing: https://dsrs.illinois.edu/students/metrics
# Processing: https://dsrs.illinois.edu/students/subscribe
#  Indexed: https://dsrs.illinois.edu/students/subscribe | Section: Internships | Title: Subscription | DSRS
# Processing: https://dsrs.illinois.edu/students#main-internship-areas
#  Indexed: https://dsrs.illinois.edu/students#main-internship-areas | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students#recruitment-process-at-dsrs
#  Indexed: https://dsrs.illinois.edu/students#recruitment-process-at-dsrs | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students#how-to-apply
#  Indexed: https://dsrs.illinois.edu/students#how-to-apply | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students#hear-from-our-interns
#  Indexed: https://dsrs.illinois.edu/students#hear-from-our-interns | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/intro#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/intro#__docusaurus_skipToContent_fallback | Section: Datasets | Title: Introduction | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category
#  Indexed: https://dsrs.illinois.edu/datahub/category | Section: Datasets | Title: DSRS Data Hub | DSRS
# Processing: https://dsrs.illinois.edu/datahub/intro#data-catalog
#  Indexed: https://dsrs.illinois.edu/datahub/intro#data-catalog | Section: Datasets | Title: Introduction | DSRS
# Processing: https://dsrs.illinois.edu/about/#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about/#__docusaurus_skipToContent_fallback | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/about/team#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about/team#__docusaurus_skipToContent_fallback | Section: Overview | Title: Team | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Team | DSRS
# Main Info: The DSRS is led by a motivated team of students with diverse backgrounds, skills, and interests. If you want to learn more about opportunities, checkhere DSRS Assistant Director of Administration DSRS Data Scientist & Unit Manager DSRS Data Scientist & Unit Manager These are our former members; DSRS...
# ---
#
# Processing: https://dsrs.illinois.edu/about/team#current-members
#  Indexed: https://dsrs.illinois.edu/about/team#current-members | Section: Overview | Title: Team | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Team | DSRS
# Main Info: The DSRS is led by a motivated team of students with diverse backgrounds, skills, and interests. If you want to learn more about opportunities, checkhere DSRS Assistant Director of Administration DSRS Data Scientist & Unit Manager DSRS Data Scientist & Unit Manager These are our former members; DSRS...
# ---
#
# Processing: https://dsrs.illinois.edu/about/team#dsrs-org-chart
#  Indexed: https://dsrs.illinois.edu/about/team#dsrs-org-chart | Section: Overview | Title: Team | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Team | DSRS
# Main Info: The DSRS is led by a motivated team of students with diverse backgrounds, skills, and interests. If you want to learn more about opportunities, checkhere DSRS Assistant Director of Administration DSRS Data Scientist & Unit Manager DSRS Data Scientist & Unit Manager These are our former members; DSRS...
# ---
#
# Processing: https://dsrs.illinois.edu/about/team#former-members-
#  Indexed: https://dsrs.illinois.edu/about/team#former-members- | Section: Overview | Title: Team | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Team | DSRS
# Main Info: The DSRS is led by a motivated team of students with diverse backgrounds, skills, and interests. If you want to learn more about opportunities, checkhere DSRS Assistant Director of Administration DSRS Data Scientist & Unit Manager DSRS Data Scientist & Unit Manager These are our former members; DSRS...
# ---
#
# Processing: https://dsrs.illinois.edu/about/infrastructure#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about/infrastructure#__docusaurus_skipToContent_fallback | Section: Overview | Title: Infrastructure | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Infrastructure | DSRS
# Main Info: The DSRS infrastructure's backbone is a high-performance computing cluster consisting of over640 cores, 2.5 TB of RAM, and over 45TB of shared storage, in addition to 2.8 TB of SSD storage. This set up provides substantial computational power to support a multitude of research projects simultaneousl...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about/faq#__docusaurus_skipToContent_fallback | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#at-a-high-level-what-can-data-science-research-service-dsrs-help-with
#  Indexed: https://dsrs.illinois.edu/about/faq#at-a-high-level-what-can-data-science-research-service-dsrs-help-with | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#what-are-the-costs-for-these-services
#  Indexed: https://dsrs.illinois.edu/about/faq#what-are-the-costs-for-these-services | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#what-does-the-process-generally-look-like
#  Indexed: https://dsrs.illinois.edu/about/faq#what-does-the-process-generally-look-like | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#im-a-student-how-can-i-get-involved
#  Indexed: https://dsrs.illinois.edu/about/faq#im-a-student-how-can-i-get-involved | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#where-can-i-find-more-information-about-becoming-an-intern
#  Indexed: https://dsrs.illinois.edu/about/faq#where-can-i-find-more-information-about-becoming-an-intern | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq#how-is-academic-credit-assigned
#  Indexed: https://dsrs.illinois.edu/about/faq#how-is-academic-credit-assigned | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about/news#__docusaurus_skipToContent_fallback | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news#-2025-
#  Indexed: https://dsrs.illinois.edu/about/news#-2025- | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news#spring
#  Indexed: https://dsrs.illinois.edu/about/news#spring | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news#-2024-
#  Indexed: https://dsrs.illinois.edu/about/news#-2024- | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news#fall
#  Indexed: https://dsrs.illinois.edu/about/news#fall | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/students/opportunities
#  Failed to fetch https://dsrs.illinois.edu/about/students/opportunities: 404 Client Error: Not Found for url: https://dsrs.illinois.edu/about/students/opportunities
# Processing: https://dsrs.illinois.edu/about/news#summer
#  Indexed: https://dsrs.illinois.edu/about/news#summer | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news#spring-1
#  Indexed: https://dsrs.illinois.edu/about/news#spring-1 | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
#
# Processing: https://dsrs.illinois.edu/about/contact#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about/contact#__docusaurus_skipToContent_fallback | Section: Overview | Title: Contact | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Contact | DSRS
# Main Info: Data Science Research Services (DSRS), Gies College of Business Matias Carrasco Kind, DSRS Director515 E Gregory Dr, Champaign, IL 61820dsrs@business.illinois.edu...
# ---
#
# Processing: https://dsrs.illinois.edu/faculty/#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/faculty/#__docusaurus_skipToContent_fallback | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty/#dsrs-services
#  Indexed: https://dsrs.illinois.edu/faculty/#dsrs-services | Section: Services | Title: Overview | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Services
# Title: Overview | DSRS
# Main Info: We assist faculty researchthrough the execution
# of statistical and data science methods, providing
# consultative services and analyses within our
# computational infrastructure. The College has invested in
# DSRS and funds the unit’s consultations and other work. We assess research studiesto determine wh...
# ---
#
# Processing: https://dsrs.illinois.edu/faculty/#assistance
#  Indexed: https://dsrs.illinois.edu/faculty/#assistance | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty/#analyses
#  Indexed: https://dsrs.illinois.edu/faculty/#analyses | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty/#data
#  Indexed: https://dsrs.illinois.edu/faculty/#data | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty/#computational-capability
#  Indexed: https://dsrs.illinois.edu/faculty/#computational-capability | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/faculty/#microsoft-azure
#  Indexed: https://dsrs.illinois.edu/faculty/#microsoft-azure | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/students/#__docusaurus_skipToContent_fallback | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/#main-internship-areas
#  Indexed: https://dsrs.illinois.edu/students/#main-internship-areas | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/#recruitment-process-at-dsrs
#  Indexed: https://dsrs.illinois.edu/students/#recruitment-process-at-dsrs | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/#how-to-apply
#  Indexed: https://dsrs.illinois.edu/students/#how-to-apply | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/#hear-from-our-interns
#  Indexed: https://dsrs.illinois.edu/students/#hear-from-our-interns | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students/opportunities#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/students/opportunities#__docusaurus_skipToContent_fallback | Section: Internships | Title: Opportunities | DSRS
# Processing: https://dsrs.illinois.edu/students/subscribe#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/students/subscribe#__docusaurus_skipToContent_fallback | Section: Internships | Title: Subscription | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category#__docusaurus_skipToContent_fallback | Section: Datasets | Title: DSRS Data Hub | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview | Section: Datasets | Title: BvD Historicals Documentation | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview | Section: Datasets | Title: Gies Consumer Credit Panel (GCCP) | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/pitchbook/overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/pitchbook/overview | Section: Datasets | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/wrds/overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/wrds/overview | Section: Datasets | Title: WRDS | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/nielsen
#  Indexed: https://dsrs.illinois.edu/datahub/category/nielsen | Section: Datasets | Title: Nielsen Datasets | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/spcapitaliq
#  Indexed: https://dsrs.illinois.edu/datahub/category/spcapitaliq | Section: Datasets | Title: S&P Capital IQ Pro | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category#links
#  Indexed: https://dsrs.illinois.edu/datahub/category#links | Section: Datasets | Title: DSRS Data Hub | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category#current-datasets
#  Indexed: https://dsrs.illinois.edu/datahub/category#current-datasets | Section: Datasets | Title: DSRS Data Hub | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#__docusaurus_skipToContent_fallback | Section: Datasets | Title: BvD Historicals Documentation | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#overview | Section: Datasets | Title: BvD Historicals Documentation | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#importance-of-dataset
#  Indexed: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#importance-of-dataset | Section: Datasets | Title: BvD Historicals Documentation | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#data-access
#  Indexed: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#data-access | Section: Datasets | Title: BvD Historicals Documentation | DSRS
# Processing: https://internal.dsrs.illinois.edu/internal/datahub/category/bvd-historicals/overview
#  Failed to fetch https://internal.dsrs.illinois.edu/internal/datahub/category/bvd-historicals/overview: 403 Client Error: Forbidden for url: https://internal.dsrs.illinois.edu/internal/datahub/category/bvd-historicals/overview
# Processing: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#support
#  Indexed: https://dsrs.illinois.edu/datahub/category/bvd-historicals/overview#support | Section: Datasets | Title: BvD Historicals Documentation | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview#__docusaurus_skipToContent_fallback | Section: Datasets | Title: Gies Consumer Credit Panel (GCCP) | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications | Section: Datasets | Title: publications | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview#overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview#overview | Section: Datasets | Title: Gies Consumer Credit Panel (GCCP) | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview#data-access
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/overview#data-access | Section: Datasets | Title: Gies Consumer Credit Panel (GCCP) | DSRS
# Processing: https://internal.dsrs.illinois.edu/internal/datahub/category/gies-consumer-credit-panel/data-access
#  Failed to fetch https://internal.dsrs.illinois.edu/internal/datahub/category/gies-consumer-credit-panel/data-access: 403 Client Error: Forbidden for url: https://internal.dsrs.illinois.edu/internal/datahub/category/gies-consumer-credit-panel/data-access
# Processing: https://dsrs.illinois.edu/datahub/category/pitchbook/overview#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/pitchbook/overview#__docusaurus_skipToContent_fallback | Section: Datasets | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/pitchbook/overview#overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/pitchbook/overview#overview | Section: Datasets | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/pitchbook/overview#how-to-get-access
#  Indexed: https://dsrs.illinois.edu/datahub/category/pitchbook/overview#how-to-get-access | Section: Datasets | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/wrds/overview#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/wrds/overview#__docusaurus_skipToContent_fallback | Section: Datasets | Title: WRDS | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/wrds/subscriptions
#  Indexed: https://dsrs.illinois.edu/datahub/category/wrds/subscriptions | Section: Datasets | Title: Subscriptions | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/wrds/overview#overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/wrds/overview#overview | Section: Datasets | Title: WRDS | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/wrds/overview#how-to-get-access
#  Indexed: https://dsrs.illinois.edu/datahub/category/wrds/overview#how-to-get-access | Section: Datasets | Title: WRDS | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/nielsen#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/nielsen#__docusaurus_skipToContent_fallback | Section: Datasets | Title: Nielsen Datasets | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/nielsen#how-to-get-access
#  Indexed: https://dsrs.illinois.edu/datahub/category/nielsen#how-to-get-access | Section: Datasets | Title: Nielsen Datasets | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/nielsen#current-datasets
#  Indexed: https://dsrs.illinois.edu/datahub/category/nielsen#current-datasets | Section: Datasets | Title: Nielsen Datasets | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/nielsen#additional-datasets-available
#  Indexed: https://dsrs.illinois.edu/datahub/category/nielsen#additional-datasets-available | Section: Datasets | Title: Nielsen Datasets | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/spcapitaliq#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/spcapitaliq#__docusaurus_skipToContent_fallback | Section: Datasets | Title: S&P Capital IQ Pro | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/spcapitaliq#how-to-get-access
#  Indexed: https://dsrs.illinois.edu/datahub/category/spcapitaliq#how-to-get-access | Section: Datasets | Title: S&P Capital IQ Pro | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#__docusaurus_skipToContent_fallback | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#introduction
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#introduction | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#data-availability-clarification
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#data-availability-clarification | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#1-attributes
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#1-attributes | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#2-bis
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#2-bis | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#3-clarity
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#3-clarity | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#4-tradelines
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#4-tradelines | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#database-schema-overview
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#database-schema-overview | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#1-attributes-1
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#1-attributes-1 | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#2-bis-1
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#2-bis-1 | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#3-clarity-1
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#3-clarity-1 | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#4-tradelines-1
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/data-overview#4-tradelines-1 | Section: Datasets | Title: GCCP Data Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications#__docusaurus_skipToContent_fallback | Section: Datasets | Title: publications | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications#publications
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications#publications | Section: Datasets | Title: publications | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications#acknowledgements
#  Indexed: https://dsrs.illinois.edu/datahub/category/gies-consumer-credit-panel/publications#acknowledgements | Section: Datasets | Title: publications | DSRS
# Processing: https://dsrs.illinois.edu/datahub/category/wrds/subscriptions#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/datahub/category/wrds/subscriptions#__docusaurus_skipToContent_fallback | Section: Datasets | Title: Subscriptions | DSRS
#
#  Exported knowledge base to dsrs_kb1.json
#
#  Stored 115 entries in dsrs_kb.json

# %% [markdown]
# ### Search by keywords

# %%
import json

def search_by_keyword_from_json(json_path="dsrs_kb1.json"):
    keyword = input("Enter keyword to search: ")
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    results = [entry for entry in data if keyword.lower() in entry.get("keywords", "").lower()]

    for entry in results:
        print(f"Title: {entry['title']}\nSection: {entry['section']}\nURL: {entry['url']}\nKeywords: {entry['keywords']}\nContent Snippet: {entry['content'][:200]}\n{'-'*80}")


search_by_keyword_from_json()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-eb0de80908c1> in <cell line: 0>()
#      12
#      13
# ---> 14 search_by_keyword_from_json()
#
# <ipython-input-16-eb0de80908c1> in search_by_keyword_from_json(json_path)
#       2
#       3 def search_by_keyword_from_json(json_path="dsrs_kb1.json"):
# ----> 4     keyword = input("Enter keyword to search: ")
#       5     with open(json_path, "r", encoding="utf-8") as f:
#       6         data = json.load(f)
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# ### This is not the submission
#
# You can try it as it has multiple URL's and uses the iterative crawl function which uses bfs approach thus not getting stuck in the recursive loop. But for the sake of this submission I am not putting it as my deliveable because it going to take really long time to execute but you can try. My focus now will be making this code run faster.

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import sqlite3
import time
import re
import pandas as pd
import json
from collections import deque # Import deque for breadth-first search

# Initialize
START_URLS = [
    "https://dsrs.illinois.edu/",
    #"https://github.com/giesdsrs",
    #"https://dsrs.illinois.edu/datahub/category",
    #"https://giesbusiness.illinois.edu/disruption-lab"
]

# Use a deque as a queue for URLs to visit
urls_to_visit = deque(START_URLS)
visited_urls = set()
extracted_data = []

# Section classifiers
SECTION_MAP = {
    "about": "Overview",
    "services": "Services",
    "projects": "Projects",
    "news": "Events",
    "tools": "Technical Resources",
    "team": "Team",
    "students": "Internships",
    "datahub": "Datasets",
    "github": "Open Source Projects",
    "disruption-lab": "Collaborations"
}

# DB Setup
def init_db():
    conn = sqlite3.connect("dsrs_kb.db")
    cursor = conn.cursor()
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS knowledge_base (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            url TEXT,
            title TEXT,
            section TEXT,
            content TEXT,
            keywords TEXT
        )
    """)
    conn.commit()
    conn.close()

def store_to_db(data):
    conn = sqlite3.connect("dsrs_kb.db")
    cursor = conn.cursor()
    cursor.executemany("""
        INSERT INTO knowledge_base (url, title, section, content, keywords)
        VALUES (?, ?, ?, ?, ?)
    """, data)
    conn.commit()
    conn.close()

def export_to_json(data, filename="dsrs_kb.json"):
    json_data = [
        {"url": entry[0], "title": entry[1], "section": entry[2], "content": entry[3], "keywords": entry[4]}
        for entry in data
    ]
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(json_data, f, indent=4, ensure_ascii=False)
    print(f"\n Exported knowledge base to {filename}")

def extract_keywords(text, top_k=5):
    words = re.findall(r'\b\w{5,}\b', text.lower())
    freq = pd.Series(words).value_counts()
    return ', '.join(freq.head(top_k).index)

def classify_section(url, title):
    for key in SECTION_MAP:
        if key in url.lower() or key in title.lower():
            return SECTION_MAP[key]
    return "Uncategorized"

def is_valid_url(url):
    parsed = urlparse(url)
    # Check if the URL belongs to one of the allowed domains
    return any(domain in parsed.netloc for domain in ["illinois.edu", "github.com"])


def crawl_iterative():
    """
    Iteratively crawl the websites starting from the given URLs using a queue.
    """
    while urls_to_visit:
        url = urls_to_visit.popleft() # Get the next URL from the left of the queue

        if url in visited_urls:
            continue
        visited_urls.add(url)

        try:
            print(f"Processing: {url}") # Added for visibility
            response = requests.get(url)
            response.raise_for_status()
        except requests.RequestException as e:
            print(f" Failed to fetch {url}: {e}")
            continue # Skip to the next URL in the queue

        soup = BeautifulSoup(response.text, 'html.parser')
        title = soup.title.string.strip() if soup.title else "No Title"
        section = classify_section(url, title)

        paragraphs = [p.get_text(strip=True) for p in soup.find_all('p') if len(p.get_text(strip=True)) > 30]
        full_text = " ".join(paragraphs)
        if not full_text:
            continue # Skip if no significant text is found

        keywords = extract_keywords(full_text)
        extracted_data.append((url, title, section, full_text, keywords))
        print(f" Indexed: {url} | Section: {section} | Title: {title}")

        if section in ["Overview", "Services", "Projects", "Technical Resources"]:
            print("\n--- Summary for Knowledge Base Users ---")
            print(f"Section: {section}")
            print(f"Title: {title}")
            print(f"Main Info: {full_text[:300]}...")
            print("---\n")

        # Add new valid links to the queue
        for link_tag in soup.find_all('a', href=True):
            full_url = urljoin(url, link_tag['href'])
            if is_valid_url(full_url) and full_url not in visited_urls:
                urls_to_visit.append(full_url)

        time.sleep(0.5)


# Execute
if __name__ == "__main__":
    init_db()
    # Call the iterative crawl function
    crawl_iterative()
    store_to_db(extracted_data)
    export_to_json(extracted_data)
    print(f"\n Stored {len(extracted_data)} entries in dsrs_kb.db and exported to dsrs_kb.json")
# Out:
# Processing: https://dsrs.illinois.edu/
#  Indexed: https://dsrs.illinois.edu/ | Section: Uncategorized | Title: DSRS | DSRS
# Processing: https://dsrs.illinois.edu/#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/#__docusaurus_skipToContent_fallback | Section: Uncategorized | Title: DSRS | DSRS
# Processing: https://dsrs.illinois.edu/about
#  Indexed: https://dsrs.illinois.edu/about | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/faculty
#  Indexed: https://dsrs.illinois.edu/faculty | Section: Uncategorized | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/students
#  Indexed: https://dsrs.illinois.edu/students | Section: Internships | Title: Overview | DSRS
# Processing: https://dsrs.illinois.edu/datahub/intro
#  Indexed: https://dsrs.illinois.edu/datahub/intro | Section: Datasets | Title: Introduction | DSRS
# Processing: https://internal.dsrs.illinois.edu
#  Failed to fetch https://internal.dsrs.illinois.edu: 403 Client Error: Forbidden for url: https://internal.dsrs.illinois.edu/
# Processing: https://inside.giesbusiness.illinois.edu/academic-units/di/dsrs
#  Indexed: https://inside.giesbusiness.illinois.edu/academic-units/di/dsrs | Section: Uncategorized | Title: Data Science Research Service | Inside | Gies College of Business | Illinois
# Processing: https://dsrs.illinois.edu/about/students
# Processing: https://dsrs.illinois.edu/about#__docusaurus_skipToContent_fallback
#  Indexed: https://dsrs.illinois.edu/about#__docusaurus_skipToContent_fallback | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/about/
#  Indexed: https://dsrs.illinois.edu/about/ | Section: Overview | Title: Introduction | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Introduction | DSRS
# Main Info: Situated at the heart of Gies College of Business, the Data Science Research Services (DSRS) exemplifies our institution's commitment to pioneering research and technological innovation. DSRS has been intricately designed to provide an unparalleled research support framework, ensuring our academic c...
# ---
#
# Processing: https://dsrs.illinois.edu/about/team
#  Indexed: https://dsrs.illinois.edu/about/team | Section: Overview | Title: Team | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Team | DSRS
# Main Info: The DSRS is led by a motivated team of students with diverse backgrounds, skills, and interests. If you want to learn more about opportunities, checkhere DSRS Assistant Director of Administration DSRS Data Scientist & Unit Manager DSRS Data Scientist & Unit Manager These are our former members; DSRS...
# ---
#
# Processing: https://dsrs.illinois.edu/about/infrastructure
#  Indexed: https://dsrs.illinois.edu/about/infrastructure | Section: Overview | Title: Infrastructure | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: Infrastructure | DSRS
# Main Info: The DSRS infrastructure's backbone is a high-performance computing cluster consisting of over640 cores, 2.5 TB of RAM, and over 45TB of shared storage, in addition to 2.8 TB of SSD storage. This set up provides substantial computational power to support a multitude of research projects simultaneousl...
# ---
#
# Processing: https://dsrs.illinois.edu/about/faq
#  Indexed: https://dsrs.illinois.edu/about/faq | Section: Overview | Title: FAQ | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: FAQ | DSRS
# Main Info: The Gies College of Business has invested in this office, thus initial consultations and work are paid for by the college, although we generally work on a first-come-first-served basis. We retain the right to prioritize projects over others depending on the availability of resources, the specific na...
# ---
#
# Processing: https://dsrs.illinois.edu/about/news
#  Indexed: https://dsrs.illinois.edu/about/news | Section: Overview | Title: News | DSRS
#
# --- Summary for Knowledge Base Users ---
# Section: Overview
# Title: News | DSRS
# Main Info: Stay Updated with DSRS! Check out the latest news, announcements, and exciting updates from our team. With mixed feelings, we wish the best for our beloved interns who are moving on to pursue full-time roles and professional growth. Congratulations to all! We are happy to announce the addition of se...
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-74da1649dff0> in <cell line: 0>()
#     141     init_db()
#     142     # Call the iterative crawl function
# --> 143     crawl_iterative()
#     144     store_to_db(extracted_data)
#     145     export_to_json(extracted_data)
#
# <ipython-input-17-74da1649dff0> in crawl_iterative()
#     134                 urls_to_visit.append(full_url) # Add to the right of the queue
#     135
# --> 136         time.sleep(1) # Be polite and avoid overwhelming the server
#     137
#     138
#
# KeyboardInterrupt:
